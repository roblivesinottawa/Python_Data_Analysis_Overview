# %% [markdown]
# # Anagrams:
#
# Anagram: 'elvis' <-> 'lives'
#
# post, spot, tops, pots, opts -> opst
#
# Sorted signature: Find anagrams by indexing words by signature

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import math
import collections

# %matplotlib inline

# %% [markdown]
# LOADING TEXT

# %%
words = []

for line in open('words.txt'):
    words.append(line)

# %%
len(words)
# Out:
# 235886

# %%
words
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n',
#  'Aaronic\n',
#  'Aaronical\n',
#  'Aaronite\n',
#  'Aaronitic\n',
#  'Aaru\n',
#  'Ab\n',
#  'aba\n',
#  'Ababdeh\n',
#  'Ababua\n',
#  'abac\n',
#  'abaca\n',
#  'abacate\n',
#  'abacay\n',
#  'abacinate\n',
#  'abacination\n',
#  'abaciscus\n',
#  'abacist\n',
#  'aback\n',
#  'abactinal\n',
#  'abactinally\n',
#  'abaction\n',
#  'abactor\n',
#  'abaculus\n',
#  'abacus\n',
#  'Abadite\n',
#  'abaff\n',
#  'abaft\n',
#  'abaisance\n',
#  'abaiser\n',
#  'abaissed\n',
#  'abalienate\n',
#  'abalienation\n',
#  'abalone\n',
#  'Abama\n',
#  'abampere\n',
#  'abandon\n',
#  'abandonable\n',
#  'abandoned\n',
#  'abandonedly\n',
#  'abandonee\n',
#  'abandoner\n',
#  'abandonment\n',
#  'Abanic\n',
#  'Abantes\n',
#  'abaptiston\n',
#  'Abarambo\n',
#  'Abaris\n',
#  'abarthrosis\n',
#  'abarticular\n',
#  'abarticulation\n',
#  'abas\n',
#  'abase\n',
# ...

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron\n'.strip().lower()
# Out:
# 'aaron'

# %%
words = []

for line in open('words.txt'):
    words.append(line.strip().lower())

# %%
words
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
# ...

# %%
words = set() # to get rid of duplicates

for line in open('words.txt'):
    words.add(line.strip().lower())

# %%
words = set()

for line in open('words.txt'):
    words.add(line.strip().lower())

# %%
words = {line.strip().lower() for line in open('words.txt', 'r')} # set comprehension

# %%
words
# Out:
# {'tasteless',
#  'quadrilobate',
#  'forwent',
#  'gelotometer',
#  'undiscolored',
#  'urinogenous',
#  'elusion',
#  'tavastian',
#  'princewood',
#  'racemocarbonate',
#  'anatoly',
#  'psilotic',
#  'comfortlessness',
#  'hooter',
#  'murthy',
#  'infatuatedly',
#  'pseudosporangium',
#  'precipitancy',
#  'excalcarate',
#  'roughhousy',
#  'autochthonism',
#  'noncommemoration',
#  'nailrod',
#  'choanoflagellate',
#  'downhill',
#  'inexpectant',
#  'russian',
#  'dissaturate',
#  'vas',
#  'upwax',
#  'gidgee',
#  'impossibilist',
#  'phraseman',
#  'bassaris',
#  'traject',
#  'luggie',
#  'vicki',
#  'exclusionist',
#  'archimperialistic',
#  'pangene',
#  'orad',
#  'biotype',
#  'cumberment',
#  'ladydom',
#  'misidentification',
#  'myrmecologist',
#  'quinamicine',
#  'unbookish',
#  'ultrafrivolous',
#  'becrown',
#  'reabuse',
#  'supraconductor',
#  'cover',
#  'onomatopoetic',
#  'squabbish',
#  'hu',
#  'cassumunar',
#  'stigmatoid',
#  'multimedial',
# ...

# %%
# sorted list
words = sorted(words)

# %%
words
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
# return a list of all the lines from an open file
open('francais.txt', 'r', encoding='latin1').readlines()
# Out:
# ['\n',
#  'a\n',
#  'ab\n',
#  'abaissa\n',
#  'abaissai\n',
#  'abaissaient\n',
#  'abaissais\n',
#  'abaissait\n',
#  'abaissant\n',
#  'abaissas\n',
#  'abaissasse\n',
#  'abaissassent\n',
#  'abaissasses\n',
#  'abaissassiez\n',
#  'abaissassions\n',
#  'abaissâmes\n',
#  'abaissât\n',
#  'abaissâtes\n',
#  'abaisse\n',
#  'abaissement\n',
#  'abaissements\n',
#  'abaissent\n',
#  'abaisser\n',
#  'abaissera\n',
#  'abaisserai\n',
#  'abaisseraient\n',
#  'abaisserais\n',
#  'abaisserait\n',
#  'abaisseras\n',
#  'abaisserez\n',
#  'abaisseriez\n',
#  'abaisserions\n',
#  'abaisserons\n',
#  'abaisseront\n',
#  'abaisses\n',
#  'abaisseur\n',
#  'abaisseurs\n',
#  'abaissez\n',
#  'abaissé\n',
#  'abaissée\n',
#  'abaissées\n',
#  'abaissés\n',
#  'abaissèrent\n',
#  'abaissiez\n',
#  'abaissions\n',
#  'abaissons\n',
#  'abandon\n',
#  'abandonna\n',
#  'abandonnai\n',
#  'abandonnaient\n',
#  'abandonnais\n',
#  'abandonnait\n',
#  'abandonnant\n',
#  'abandonnas\n',
# ...

# %% [markdown]
# finding anagrams

# %%
words[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted("aaron") # returns each character in the string in alphabetical order
# Out:
# ['a', 'a', 'n', 'o', 'r']

# %%
sorted("elvis") == sorted("lives") # True
# Out:
# True

# %%
sorted("elvis") == sorted("sings") # False
# Out:
# False

# %%
'-'.join(sorted("aaron"))
# Out:
# 'a-a-n-o-r'

# %%
'*'.join(sorted("aaron"))
# Out:
# 'a*a*n*o*r'

# %%
''.join(sorted("aaron"))
# Out:
# 'aanor'

# %%
def signature(word):
    return ''.join(sorted(word))

# %%
def find_anagrams(myword):
    return [word for word in words if signature(myword) == signature(word)]

# %%
find_anagrams('dictionary')
# Out:
# ['dictionary', 'indicatory']

# %%
find_anagrams('aaron')
# Out:
# ['aaron']

# %%
# %time find_anagrams('elvis')
# Out:
# CPU times: user 363 ms, sys: 4.85 ms, total: 367 ms
# Wall time: 375 ms
# ['elvis', 'levis', 'slive']
